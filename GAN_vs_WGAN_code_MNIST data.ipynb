# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
import argparse
import subprocess
import json

from tensorflow.keras import layers
from IPython import display


def run(input,model_parameters):
  if input:
    model_param = take_input()
  else:
    model_param = model_parameters
  
  make_dir_if_not_exists(model_param.get("output"))
  #if not os.path.exists(model_param.get("output")) or not os.path.isdir(model_param.get("output")):
        #raise OSError("Output path does not exist or is not a directory.")
  
  model_param['output'] = os.path.normpath(model_param.get("output"))
  
  if model_param.get("model") == "GAN":
    model = GAN(model_param)
  else:
    model = WGAN_LP(model_param)

  model.train()

  # randomly generate 100 samples
  if model_param.get("visualize"):
      vis_seed = tf.random.uniform([100, model.noise_dim])
      vis_gen = model.G(vis_seed, training=False)
      if model_param.get("dataset") == "MNIST":
          plt.figure(figsize=(4.8, 4.8))
      else:
          plt.figure(figsize=(5.4, 5.4))
      for i in range(vis_gen.shape[0]):
          x_pos = i % 10
          y_pos = int(i / 10)
          if model_param.get("dataset") == "MNIST":
              plt.figimage(vis_gen[i, :, :, 0] * 127.5 + 127.5,
                            10 + x_pos * (28 + 5), 10 + y_pos * (28 + 5), cmap='gray')
          else:
              plt.figimage((vis_gen[i, :, :] + 1) / 2,
                            10 + x_pos * (32 + 5), 10 + y_pos * (32 + 5))
          plt.axis('off')
      make_dir_if_not_exists(os.path.join(model_param.get("output"),
                                "{}_{}_Example.png".format(model_param.get("model"), model_param.get("dataset"))))    
      plt.savefig(os.path.join(model_param.get("output"),
                                "{}_{}_Example.png".format(model_param.get("model"), model_param.get("dataset"))))

      # plot median value of the objective functions
      plt.figure()#initializing the plot
      plt.title("Objective Functions of {} (Dataset: {})".format(model_param.get("model"), model_param.get("dataset")))#create title
      plt.xlabel("Epoch")
      plt.ylabel("Median Value")
      plt.plot(range(1, 1 + model_param.get("total_epoch")), np.median(model.d_obj, axis=[-0, -1]))#discriminator
      plt.plot(range(1, 1 + model_param.get("total_epoch")), np.median(model.g_obj, axis=[-0]))#generator
      plt.legend(['Discriminator', 'Generator'])
      plt.savefig(os.path.join(model_param.get("output"),
                                "{}_{}_Objective.png".format(model_param.get("model"), model_param.get("dataset"))))
  if model_param.get("gif"):
      model.make_gif(model_param)


class GAN:
    def __init__(self, param):
        # load data
        self.dataset = param.get("dataset", -1)

        # choose CNN setup for the dataset
        if self.dataset == "MNIST":
            (self.x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
            self.init_dim = 7
            self.strides = (1, 2, 2)
            self.data_shape = self.x_train.shape + (1,)
        elif self.dataset == "CIFAR10":
            (self.x_train, _), (_, _) = tf.keras.datasets.cifar10.load_data()
            self.init_dim = 4
            self.strides = (2, 2, 2)
            self.data_shape = self.x_train.shape
        else:
            raise ValueError('Dataset not supported.')

        # get basic inputs
        self.batch_size = param.get("batch_size", 128)
        self.noise_dim = param.get("noise_dim", 128)
        self.total_epoch = param.get("total_epoch", 100)
        self.critic_step = param.get("critic_step", 1)
        self.visualize = param.get("visualize", True)
        self.out_path = param.get("output", "/content/gdrive/My Drive/GANvWGAN/fileoutputs")

        # storage for the objectives
        self.batch_num = int(self.data_shape[0] / self.batch_size) + (self.data_shape[0] % self.batch_size != 0)
        self.d_obj = np.zeros([self.batch_num, self.total_epoch, self.critic_step])
        self.g_obj = np.zeros([self.batch_num, self.total_epoch])

        # normalize dataset
        self.x_train = self.x_train.reshape(self.data_shape).astype('float32')
        self.x_train = (self.x_train - 127.5) / 127.5  # Normalize RGB to [-1, 1]
        self.x_train = \
            tf.data.Dataset.from_tensor_slices(self.x_train).shuffle(self.data_shape[0]).batch(self.batch_size)

        # setup optimizers
        self.G_optimizer = tf.keras.optimizers.Adam(learning_rate=param.get("learning_rate_g", 5e-5),
                                                    beta_1=param.get("beta_1_g", 0.5),
                                                    beta_2=param.get("beta_2_g", 0.999),
                                                    epsilon=param.get("epsilon_g", 1e-7),
                                                    amsgrad=param.get("amsgrad_g", False))
        self.D_optimizer = tf.keras.optimizers.Adam(learning_rate=param.get("learning_rate_d", 1e-4),
                                                    beta_1=param.get("beta_1_d", 0.5),
                                                    beta_2=param.get("beta_2_d", 0.999),
                                                    epsilon=param.get("epsilon_d", 1e-7),
                                                    amsgrad=param.get("amsgrad_d", False))
        # setup models
        self.G = self.set_generator()
        self.D = self.set_discriminator()

    def set_generator(self):
        g = tf.keras.Sequential()
        g.add(layers.Dense(self.init_dim * self.init_dim * 256, use_bias=False, input_shape=(self.noise_dim,)))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())
        g.add(layers.Reshape((self.init_dim, self.init_dim, 256)))

        g.add(layers.Conv2DTranspose(128, 5, strides=self.strides[0], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(64, 5, strides=self.strides[1], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(32, 5, strides=self.strides[2], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(self.data_shape[3], 5, padding='same', use_bias=False, activation='tanh'))

        return g

    def set_discriminator(self):
        d = tf.keras.Sequential()
        d.add(layers.Conv2D(32, kernel_size=5, strides=2, padding='same',
                            input_shape=self.data_shape[1:],
                            kernel_initializer="glorot_uniform"))
        d.add(layers.LeakyReLU())

        d.add(layers.Conv2D(64, kernel_size=5, strides=2, padding='same'))
        d.add(layers.BatchNormalization())
        d.add(layers.LeakyReLU())

        d.add(layers.Conv2D(128, kernel_size=5, strides=2, padding='same'))
        d.add(layers.BatchNormalization())
        d.add(layers.LeakyReLU())
        d.add(layers.Dropout(0.5))

        d.add(layers.Conv2D(256, kernel_size=5, strides=2, padding='same'))
        d.add(layers.BatchNormalization())
        d.add(layers.LeakyReLU())

        d.add(layers.Flatten())
        d.add(layers.Dense(2, activation='softmax'))
        d.add(layers.Lambda(lambda x: x[:, 0]))

        return d

    @tf.function
    def train_discriminator(self, x_batch):
        with tf.GradientTape() as D_tape:
          x_gen = self.G(tf.random.uniform([x_batch.shape[0], self.noise_dim]), training=True)
          y_real = self.D(x_batch, training=True)
          y_gen = self.D(x_gen, training=True)

          # compute the objective
          loss_real = tf.math.log(tf.clip_by_value(y_real, 1e-10, 1.0))
          loss_gen = tf.math.log(tf.clip_by_value(tf.math.add(1.0, tf.math.negative(y_gen)), 1e-10, 1.0))
          d_obj = -tf.math.reduce_mean(loss_real) - tf.math.reduce_mean(loss_gen)
          # update the discriminator
          d_grad = D_tape.gradient(d_obj, self.D.trainable_variables)
          self.D_optimizer.apply_gradients(zip(d_grad, self.D.trainable_variables))
            
        return d_obj

    @tf.function
    def train_generator(self, x_batch_size):
        with tf.GradientTape() as G_tape:
          x_gen = self.G(tf.random.uniform([x_batch_size, self.noise_dim]), training=True)
          y_gen = self.D(x_gen, training=True)

          # compute the objective
          #g_obj = -tf.math.reduce_mean(tf.math.log(tf.clip_by_value(y_gen, 1e-10, 1.0)))
          g_obj = tf.math.reduce_mean(tf.math.log(tf.clip_by_value(tf.math.add(1.0, tf.math.negative(y_gen)), 1e-10, 1.0)))
          # update the generator
          g_grad = G_tape.gradient(g_obj, self.G.trainable_variables)
          self.G_optimizer.apply_gradients(zip(g_grad, self.G.trainable_variables))

        return g_obj

    def train(self):
        vis_seed = None
        if self.visualize:
            # Seed for checking training progress
            vis_seed = tf.random.uniform([16, self.noise_dim])

        # Record current time and start training
        print("Training...")
        ts_start = tf.timestamp()
        for t in range(self.total_epoch):
            batch_id = 0
            for b in self.x_train:
                for k in range(self.critic_step):
                    self.d_obj[batch_id, t, k] = self.train_discriminator(b)
                #print(self.train_generator(self.batch_size))    
                self.g_obj[batch_id, t] = self.train_generator(b.shape[0])
                batch_id += 1
            
            # checkpoint_dir = './training_checkpoints/'
            # checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
            # checkpoint = tf.train.Checkpoint(generator_optimizer=self.G_optimizer,
            #                                 discriminator_optimizer=self.D_optimizer,
            #                                 generator=self.G,
            #                                 discriminator=self.D)

            # # Save the model every epoch
            # if (t + 1) % 1 == 0:
            #   checkpoint.save(file_prefix = checkpoint_prefix)
            
            ckpt_folderD = self.out_path+"/checkpointsD/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderD)
            ckpt_folderG = self.out_path+"/checkpointsG/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderG)
            ckpt_folderDopt = self.out_path+"/checkpointsDopt/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderDopt)
            ckpt_folderGopt = self.out_path+"/checkpointsGopt/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderGopt)
            ckpt_filename = self.out_path+"/objectivefnvals/epoch_{}.txt".format(t)
            make_dir_if_not_exists(ckpt_filename)
            names = {'d_obj','g_obj'}
            tf.saved_model.save(self.D,export_dir=ckpt_folderD)
            tf.saved_model.save(self.G,export_dir=ckpt_folderG)
            tf.saved_model.save(self.D_optimizer,export_dir=ckpt_folderDopt)
            tf.saved_model.save(self.G_optimizer,export_dir=ckpt_folderGopt)

          
            with open(ckpt_filename,"w") as f:
              f.write(str({ key:value for key,value in self.__dict__.items() if key in names}))
  

            # Print time
            print("Time used for epoch {} are {:0.2f} seconds.".format(t + 1, tf.timestamp() - ts_start))

            # Check current generator
            if self.visualize:
                vis_gen = self.G(vis_seed, training=False)
                fig = plt.figure(figsize=(4, 4))
                plt.suptitle('Epoch: {:03d}'.format(t + 1))
                for i in range(vis_gen.shape[0]):
                    plt.subplot(4, 4, i + 1)
                    if self.data_shape[3] == 1:
                        plt.imshow(vis_gen[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
                    else:
                        plt.imshow((vis_gen[i, :, :] + 1) / 2)
                    plt.axis('off')
                make_dir_if_not_exists(os.path.join(self.out_path, "GAN_{}_Epoch_{:03d}.png".format(self.dataset, t + 1)))
                plt.savefig(os.path.join(self.out_path, "GAN_{}_Epoch_{:03d}.png".format(self.dataset, t + 1)))
                plt.clf()
                plt.close(fig)
        print("Done! {:0.2f} seconds have passed.".format(tf.timestamp() - ts_start))

    def restore_ckpt(self):
      # checkpoint_dir = checkpoint_dir = self.out_path + '/training_checkpoints/'
      # checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
      os.chdir(self.out_path+"/checkpointsD")
      latest_ckptD = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsG")
      latest_ckptG = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsDopt")
      latest_ckptDopt = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsGopt")
      latest_ckptGopt = sorted(glob.glob("epoch_*"),reverse=True)[0]

      # with open(latest_ckpt,"r") as f:
      #   d = eval(f.read())

      # for key, value in d.items():
      #   self.__dict__[key] = d[key]

      importedD = tf.saved_model.load(latest_ckptD)
      importedG = tf.saved_model.load(latest_ckptG)
      importedDopt = tf.saved_model.load(latest_ckptDopt)
      importedGopt = tf.saved_model.load(latest_ckptGopt)

      self.D = importedD
      self.G = importedG
      self.Dopt = importedDopt
      self.Gopt = importedGopt
      
      os.chdir(self.out_path)

    def display_image(self,epoch_no,example=False):
      if example:
        return PIL.Image.open(os.path.join(self.out_path,"GAN_{}_Example.png".format(self.dataset)))
      else:
        return PIL.Image.open(os.path.join(self.out_path, "GAN_{}_Epoch_{:03d}.png".format(self.dataset,epoch_no)))
    
    def make_gif(self,model_param):
      anim_file = "{}_{}_totalepoch{}.gif".format(model_param.get("dataset"),model_param.get("model"),model_param.get("total_epoch"))

      os.chdir(model_param.get("output"))
      filenames = glob.glob('GAN_{}_Epoch_*.png'.format(model_param.get("dataset")))
      filenames = sorted(filenames)
      image=[]
      for i,filename in enumerate(filenames):
        image.append(imageio.imread(filename))
        imageio.mimsave("./"+anim_file,iter(image))
          
      import IPython
      if IPython.version_info > (6,2,0,''):
        display.Image(filename=anim_file)

class WGAN_LP:
    def __init__(self, param):
        # load data
        self.dataset = param.get("dataset", -1)

        # choose CNN setup for each dataset
        if self.dataset == "MNIST":
            (self.x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
            self.init_dim = 7
            self.strides = (2, 2, 1)
            self.data_shape = self.x_train.shape + (1,)
        elif self.dataset == "CIFAR10":
            (self.x_train, _), (_, _) = tf.keras.datasets.cifar10.load_data()
            self.init_dim = 2
            self.strides = (2, 2, 2)
            self.data_shape = self.x_train.shape
        else:
            raise ValueError('Dataset not supported.')

        # get basic inputs
        self.batch_size = param.get("batch_size", 128)
        self.noise_dim = param.get("noise_dim", 128)
        self.total_epoch = param.get("total_epoch", 100)
        self.critic_step = param.get("critic_step", 1)
        self.visualize = param.get("visualize", True)
        self.out_path = param.get("output", "/content/gdrive/My Drive/GANvWGAN/fileoutputs")


        # storage for the objectives
        self.batch_num = int(self.data_shape[0] / self.batch_size) + (self.data_shape[0] % self.batch_size != 0)
        self.d_obj = np.zeros([self.batch_num, self.total_epoch, self.critic_step])
        self.g_obj = np.zeros([self.batch_num, self.total_epoch])

        # set regularization parameters
        self.grad_penalty = param.get("grad_penalty", 10.0)
        self.perturb_factor = param.get("perturb_factor", 1.0)

        # normalize dataset
        self.x_train = self.x_train.reshape(self.data_shape).astype('float32')
        self.x_train = (self.x_train - 127.5) / 127.5  # Normalize RGB to [-1, 1]
        self.x_train = \
            tf.data.Dataset.from_tensor_slices(self.x_train).shuffle(self.data_shape[0]).batch(self.batch_size)

        # setup optimizers
        self.D_optimizer = tf.keras.optimizers.Adam(learning_rate=param.get("learning_rate_d", 1e-4),
                                                    beta_1=param.get("beta_1_d", 0.5),
                                                    beta_2=param.get("beta_2_d", 0.999),
                                                    epsilon=param.get("epsilon_d", 1e-7),
                                                    amsgrad=param.get("amsgrad_d", False))
        self.G_optimizer = tf.keras.optimizers.Adam(learning_rate=param.get("learning_rate_g", 5e-5),
                                                    beta_1=param.get("beta_1_g", 0.2),
                                                    beta_2=param.get("beta_2_g", 0.999),
                                                    epsilon=param.get("epsilon_g", 1e-7),
                                                    amsgrad=param.get("amsgrad_g", False))

        # setup models
        self.G = self.set_generator()
        self.D = self.set_discriminator()

    def set_generator(self):
        g = tf.keras.Sequential()
        g.add(layers.Dense(self.init_dim * self.init_dim * 256, use_bias=False, input_shape=(self.noise_dim,)))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())
        g.add(layers.Reshape((self.init_dim, self.init_dim, 256)))

        g.add(layers.Conv2DTranspose(128, 5, strides=self.strides[0], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(64, 5, strides=self.strides[1], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(32, 5, strides=self.strides[2], padding='same', use_bias=False))
        g.add(layers.BatchNormalization())
        g.add(layers.LeakyReLU())

        g.add(layers.Conv2DTranspose(self.data_shape[3], 5, strides=self.strides[2],
                                     padding='same', use_bias=False, activation='tanh'))

        return g

    def set_discriminator(self):
        d = tf.keras.Sequential()
        d.add(layers.Conv2D(32, kernel_size=5, strides=2, padding='same', input_shape=self.data_shape[1:]))
        d.add(layers.LeakyReLU())

        d.add(layers.Conv2D(64, kernel_size=5, strides=2, padding='same'))
        d.add(layers.LayerNormalization())
        d.add(layers.LeakyReLU())

        d.add(layers.Conv2D(128, kernel_size=5, strides=2, padding='same'))
        d.add(layers.LayerNormalization())
        d.add(layers.LeakyReLU())

        d.add(layers.Flatten())
        d.add(layers.Dense(1))

        return d

    @tf.function
    def lipschitz_penalty(self, x, x_hat):
        # DRAGAN-like sampling scheme
        x_join = tf.concat([x, x_hat], axis=0)
        _, batch_var = tf.nn.moments(x_join, axes=[0, 1, 2, 3])
        delta = tf.random.normal(x_join.shape, stddev=self.perturb_factor * tf.sqrt(batch_var))
        x_tilde = x_join + delta

        # compute gradient penalty
        with tf.GradientTape() as D_tape:
            D_tape.watch(x_tilde)
            y_tilde = self.D(x_tilde)
        d_grad = D_tape.gradient(y_tilde, x_tilde)
        grad_norm = tf.sqrt(tf.reduce_sum(tf.square(d_grad), axis=[1, 2, 3]))

        return tf.reduce_mean(tf.square(tf.maximum(0.0, grad_norm - 1.0)))

    @tf.function
    def train_discriminator(self, x_batch):
        with tf.GradientTape() as D_tape:
            # sample data
            x_gen = self.G(tf.random.uniform([x_batch.shape[0], self.noise_dim]), training=True)

            # scoring with the discriminator
            y_real = self.D(x_batch, training=True)
            y_gen = self.D(x_gen, training=True)

            # compute the objective
            d_obj = tf.math.reduce_mean(y_gen) - tf.math.reduce_mean(y_real)
            d_obj_pen = d_obj + self.grad_penalty * self.lipschitz_penalty(x_batch, x_gen)
            # update the discriminator
            d_grad = D_tape.gradient(d_obj_pen, self.D.trainable_variables)
            self.D_optimizer.apply_gradients(zip(d_grad, self.D.trainable_variables))

        return d_obj

    @tf.function
    def train_generator(self, x_batch_size):
        with tf.GradientTape() as G_tape:
            x_gen = self.G(tf.random.uniform([x_batch_size, self.noise_dim]), training=True)
            y_gen = self.D(x_gen, training=True)

            # compute the objective
            g_obj = -tf.math.reduce_mean(y_gen)
            # update the generator
            g_grad = G_tape.gradient(g_obj, self.G.trainable_variables)
            self.G_optimizer.apply_gradients(zip(g_grad, self.G.trainable_variables))

        return g_obj

    def train(self):
        vis_seed = None
        if self.visualize:
            # Seed for checking training progress
            vis_seed = tf.random.uniform([16, self.noise_dim])

        # Record current time and start training
        print("Training...")
        ts_start = tf.timestamp()
        for t in range(self.total_epoch):
            batch_id = 0
            for b in self.x_train:
                for k in range(self.critic_step):
                    self.d_obj[batch_id, t, k] = self.train_discriminator(b)
                self.g_obj[batch_id, t] = self.train_generator(b.shape[0])
                batch_id += 1
            
            # checkpoint_dir = self.out_path + '/training_checkpoints/'
            # checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
            # checkpoint = tf.train.Checkpoint(generator_optimizer=self.G_optimizer,
            #                                 discriminator_optimizer=self.D_optimizer,
            #                                 generator=self.G,
            #                                 discriminator=self.D)

            # # Save the model every epoch
            # if (t + 1) % 1 == 0:
            #   checkpoint.save(file_prefix = checkpoint_prefix)

            ckpt_folderD = self.out_path+"/checkpointsD/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderD)
            ckpt_folderG = self.out_path+"/checkpointsG/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderG)
            ckpt_folderDopt = self.out_path+"/checkpointsDopt/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderDopt)
            ckpt_folderGopt = self.out_path+"/checkpointsGopt/epoch_{}".format(t)
            make_dir_if_not_exists(ckpt_folderGopt)
            ckpt_filename = self.out_path+"/objectivefnvals/epoch_{}.txt".format(t)
            make_dir_if_not_exists(ckpt_filename)
            names = {'d_obj','g_obj'}
            tf.saved_model.save(self.D,export_dir=ckpt_folderD)
            tf.saved_model.save(self.G,export_dir=ckpt_folderG)
            tf.saved_model.save(self.D_optimizer,export_dir=ckpt_folderDopt)
            tf.saved_model.save(self.G_optimizer,export_dir=ckpt_folderGopt)

          
            with open(ckpt_filename,"w") as f:
              f.write(str({ key:value for key,value in self.__dict__.items() if key in names}))
  

            # Print time
            print("Time used for epoch {} are {:0.2f} seconds.".format(t + 1, tf.timestamp() - ts_start))

            # Check current generator
            if self.visualize:
                vis_gen = self.G(vis_seed, training=False)
                fig = plt.figure(figsize=(4, 4))
                plt.suptitle('Epoch: {:03d}'.format(t + 1))
                for i in range(vis_gen.shape[0]):
                    plt.subplot(4, 4, i + 1)
                    if self.data_shape[3] == 1:
                        plt.imshow(vis_gen[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
                    else:
                        plt.imshow((vis_gen[i, :, :] + 1) / 2)
                    plt.axis('off')
                make_dir_if_not_exists(os.path.join(self.out_path, "WGAN_LP_{}_Epoch_{:03d}.png".format(self.dataset, t + 1)))
                plt.savefig(os.path.join(self.out_path, "WGAN_LP_{}_Epoch_{:03d}.png".format(self.dataset, t + 1)))
                plt.clf()
                plt.close(fig)
        print("Done! {:0.2f} seconds have passed.".format(tf.timestamp() - ts_start))
    
    def restore_ckpt(self):
      # checkpoint_dir = checkpoint_dir = self.out_path + '/training_checkpoints/'
      # checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
      os.chdir(self.out_path+"/checkpointsD")
      latest_ckptD = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsG")
      latest_ckptG = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsDopt")
      latest_ckptDopt = sorted(glob.glob("epoch_*"),reverse=True)[0]
      os.chdir(self.out_path+"/checkpointsGopt")
      latest_ckptGopt = sorted(glob.glob("epoch_*"),reverse=True)[0]

      # with open(latest_ckpt,"r") as f:
      #   d = eval(f.read())

      # for key, value in d.items():
      #   self.__dict__[key] = d[key]

      importedD = tf.saved_model.load(latest_ckptD)
      importedG = tf.saved_model.load(latest_ckptG)
      importedDopt = tf.saved_model.load(latest_ckptDopt)
      importedGopt = tf.saved_model.load(latest_ckptGopt)

      self.D = importedD
      self.G = importedG
      self.Dopt = importedDopt
      self.Gopt = importedGopt
      
      os.chdir(self.out_path)

    def display_image(self,epoch_no):
      return PIL.Image.open(os.path.join(self.out_path, "WGAN_LP_{}_Epoch_{:03d}.png".format(self.dataset,epoch_no)))
    
    def display_image(self,epoch_no,example=False):
      if example:
        return PIL.Image.open(os.path.join(self.out_path,"WGANLP_{}_Example.png".format(self.dataset)))
      else:
        return PIL.Image.open(os.path.join(self.out_path, "WGAN_LP_{}_Epoch_{:03d}.png".format(self.dataset,epoch_no)))

    def make_gif(self,model_param):
      anim_file = "{}_{}_totalepoch{}.gif".format(model_param.get("dataset"),model_param.get("model"),model_param.get("total_epoch"))

      os.chdir(model_param.get("output"))
      filenames = glob.glob('WGAN_LP_{}_Epoch_*.png'.format(model_param.get("dataset")))
      filenames = sorted(filenames)
      image=[]
      for i,filename in enumerate(filenames):
        image.append(imageio.imread(filename))
        imageio.mimsave("./"+anim_file,iter(image))
          
      import IPython
      if IPython.version_info > (6,2,0,''):
        display.Image(filename=anim_file)


def _get_params_dir():
    from pathlib import Path
    return os.path.join(Path.home(), 'GanvWGAN')

def make_dir_if_not_exists(save_file):
    """Utility function for creating necessary dictories for a specified filename.
    Parameters
    ----------
    save_file : :obj:`str`
        absolute path of save file
    """
    save_dir = os.path.dirname(save_file)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
def take_input():
    """Set up information about the model"""

    model_param = {
        'model': ['Model to fit GAN/WGANLP: ', str],
        'dataset': ['Dataset to use MNIST/CIFAR10: ', str],
        'output': ['Directory to save the output: ', str],
        'batch_size': ['Size of the batch used in training: ', int],
        'noise_dim': ['Dimension of the latent noise: ', int],
        'total_epoch': ['Number of training epochs: ', int],
        'critic_step': ['The number of steps to apply to the discriminator: ', int],
        'visualize': ['Do you want to visualize the training process and the resulting models? (True/False): ', bool],
        'gif': ['Do you want to mae a gif of the images generated at each epoch? (True/False): ', bool],

        # setup the discriminator optimizer
        'learning_rate_d': ['The learning rates of ADAM (discriminator):', float],
        'beta_1_d': ['The exponential decay rates for the 1st moment estimates in ADAM (discriminator): ', float],
        'beta_2_d': ['The exponential decay rates for the 2nd moment estimates in ADAM (discriminator): ', float],
        'epsilon_d': ['Small constants for numerical stability of ADAM (discriminator): ', float],
        'amsgrad_d': ['Logical indicating whether to use the AMSGrad variant of ADAM (discriminator): ', bool],

        # setup the generator optimizer
        'learning_rate_g': ['The learning rates of ADAM (discriminator):', float],
        'beta_1_g': ['The exponential decay rates for the 1st moment estimates in ADAM (discriminator): ', float],
        'beta_2_g': ['The exponential decay rates for the 2nd moment estimates in ADAM (discriminator): ', float],
        'epsilon_g': ['Small constants for numerical stability of ADAM (discriminator): ', float],
        'amsgrad_g': ['Logical indicating whether to use the AMSGrad variant of ADAM (discriminator): ', bool]
    }

    print('Please enter the following information:')
    for key, val in model_param.items():
        if val[1] == bool:
            model_param[key] = True if input(val[0]).lower() == 'true' else False
        else:
            model_param[key] = val[1](input(val[0]))

    if model_param.get("model") == "WGANLP":
        params_WGANLP = {
            'grad_penalty': ['Penalty controlling the strength of the gradient regularization in WGAN-LP:' , float],
            'perturb_factor': ['Factor controlling the standard deviation of perturbation for generating samples to compute the gradient penalty in WGAN-LP:', float],
        }
        print('Please enter the following information for WGAN-LP:')
        for key, val in params_WGANLP.items():
            if val[1] == bool:
                params_WGANLP[key] = True if input(val[0]).lower() == 'true' else False
            else:
                params_WGANLP[key] = val[1](input(val[0]))
    
    params_dir = _get_params_dir()
    if not os.path.exists(params_dir):
        os.makedirs(params_dir)
    params_file = os.path.join(
        params_dir, str('%s_%s_params.json' % (model_param['dataset'], model_param['model'])))
    with open(params_file, 'w') as f:
        json.dump(model_param, f, sort_keys=False, indent=4)

    # print('Dataset params are now stored in %s' % params_file)

    return model_param

# %%
os.chdir('/content/drive/My Drive')

# %%
model_param = {'amsgrad_d': False,
 'amsgrad_g': False,
 'batch_size': 128,
 'beta_1_d': 0.2,
 'beta_1_g': 0.5,
 'beta_2_d': 0.999,
 'beta_2_g': 0.999,
 'critic_step': 1,
 'dataset': 'MNIST',
 'epsilon_d': 1e-07,
 'epsilon_g': 1e-07,
 'learning_rate_d': 0.0001,
 'learning_rate_g': 0.0001,
 'model': 'WGANLP',
 'noise_dim': 128,
 'output': '/content/drive/My Drive/GANvWGAN/WGAN1stattempt',
 'total_epoch': 100,
 'visualize': True,
  'gif': True}

# %%
model_param_WGANfull100 = {'amsgrad_d': False,
 'amsgrad_g': False,
 'batch_size': 128,
 'beta_1_d': 0.2,
 'beta_1_g': 0.5,
 'beta_2_d': 0.999,
 'beta_2_g': 0.999,
 'critic_step': 1,
 'dataset': 'MNIST',
 'epsilon_d': 1e-07,
 'epsilon_g': 1e-07,
 'learning_rate_d': 0.0001,
 'learning_rate_g': 0.0001,
 'model': 'WGANLP',
 'noise_dim': 128,
 'output': '/content/drive/My Drive/GANvWGAN/WGAN2ndattempt',
 'total_epoch': 100,
 'visualize': True,
  'gif': True}

# %%
import random
random.seed(0)
run(False,model_param_WGANfull100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Training...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_0/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_0/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_0/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_0/assets
# Time used for epoch 1 are 59.24 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_1/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_1/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_1/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_1/assets
# Time used for epoch 2 are 107.39 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_2/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_2/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_2/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_2/assets
# Time used for epoch 3 are 156.23 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_3/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_3/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_3/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_3/assets
# Time used for epoch 4 are 204.83 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_4/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_4/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_4/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_4/assets
# Time used for epoch 5 are 253.58 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_5/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_5/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_5/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_5/assets
# Time used for epoch 6 are 302.38 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_6/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_6/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_6/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_6/assets
# Time used for epoch 7 are 351.34 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_7/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_7/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_7/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_7/assets
# Time used for epoch 8 are 399.92 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_8/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_8/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_8/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_8/assets
# Time used for epoch 9 are 448.39 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_9/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_9/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_9/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_9/assets
# Time used for epoch 10 are 496.99 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_10/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_10/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_10/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_10/assets
# Time used for epoch 11 are 545.36 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_11/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_11/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_11/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_11/assets
# Time used for epoch 12 are 593.81 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_12/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_12/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_12/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_12/assets
# Time used for epoch 13 are 642.18 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_13/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_13/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_13/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_13/assets
# Time used for epoch 14 are 690.50 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_14/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_14/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_14/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_14/assets
# Time used for epoch 15 are 738.75 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_15/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_15/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_15/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_15/assets
# Time used for epoch 16 are 787.11 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_16/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_16/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_16/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_16/assets
# Time used for epoch 17 are 835.49 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_17/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_17/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_17/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_17/assets
# Time used for epoch 18 are 883.81 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_18/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_18/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_18/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_18/assets
# Time used for epoch 19 are 932.21 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_19/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_19/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_19/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_19/assets
# Time used for epoch 20 are 980.56 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_20/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_20/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_20/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_20/assets
# Time used for epoch 21 are 1028.89 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_21/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_21/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_21/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_21/assets
# Time used for epoch 22 are 1077.12 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_22/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_22/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_22/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_22/assets
# Time used for epoch 23 are 1125.60 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_23/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_23/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_23/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_23/assets
# Time used for epoch 24 are 1173.91 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_24/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_24/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_24/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_24/assets
# Time used for epoch 25 are 1222.27 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_25/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_25/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_25/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_25/assets
# Time used for epoch 26 are 1270.63 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_26/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_26/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_26/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_26/assets
# Time used for epoch 27 are 1318.77 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_27/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_27/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_27/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_27/assets
# Time used for epoch 28 are 1366.96 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_28/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_28/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_28/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_28/assets
# Time used for epoch 29 are 1415.20 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_29/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_29/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_29/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_29/assets
# Time used for epoch 30 are 1463.49 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_30/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_30/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_30/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_30/assets
# Time used for epoch 31 are 1511.74 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_31/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_31/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_31/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_31/assets
# Time used for epoch 32 are 1560.00 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_32/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_32/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_32/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_32/assets
# Time used for epoch 33 are 1608.30 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_33/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_33/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_33/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_33/assets
# Time used for epoch 34 are 1656.65 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_34/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_34/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_34/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_34/assets
# Time used for epoch 35 are 1705.00 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_35/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_35/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_35/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_35/assets
# Time used for epoch 36 are 1753.48 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_36/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_36/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_36/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_36/assets
# Time used for epoch 37 are 1802.32 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_37/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_37/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_37/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_37/assets
# Time used for epoch 38 are 1851.05 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_38/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_38/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_38/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_38/assets
# Time used for epoch 39 are 1899.80 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_39/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_39/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_39/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_39/assets
# Time used for epoch 40 are 1948.49 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_40/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_40/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_40/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_40/assets
# Time used for epoch 41 are 1997.12 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_41/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_41/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_41/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_41/assets
# Time used for epoch 42 are 2045.69 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_42/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_42/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_42/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_42/assets
# Time used for epoch 43 are 2094.30 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_43/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_43/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_43/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_43/assets
# Time used for epoch 44 are 2142.94 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_44/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_44/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_44/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_44/assets
# Time used for epoch 45 are 2191.55 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_45/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_45/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_45/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_45/assets
# Time used for epoch 46 are 2240.16 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_46/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_46/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_46/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_46/assets
# Time used for epoch 47 are 2288.80 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_47/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_47/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_47/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_47/assets
# Time used for epoch 48 are 2337.34 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_48/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_48/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_48/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_48/assets
# Time used for epoch 49 are 2386.03 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_49/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_49/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_49/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_49/assets
# Time used for epoch 50 are 2434.53 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_50/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_50/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_50/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_50/assets
# Time used for epoch 51 are 2483.11 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_51/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_51/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_51/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_51/assets
# Time used for epoch 52 are 2531.71 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_52/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_52/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_52/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_52/assets
# Time used for epoch 53 are 2580.42 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_53/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_53/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_53/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_53/assets
# Time used for epoch 54 are 2628.93 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_54/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_54/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_54/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_54/assets
# Time used for epoch 55 are 2677.50 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_55/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_55/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_55/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_55/assets
# Time used for epoch 56 are 2726.05 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_56/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_56/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_56/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_56/assets
# Time used for epoch 57 are 2774.80 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_57/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_57/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_57/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_57/assets
# Time used for epoch 58 are 2823.43 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_58/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_58/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_58/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_58/assets
# Time used for epoch 59 are 2872.09 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_59/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_59/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_59/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_59/assets
# Time used for epoch 60 are 2920.72 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_60/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_60/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_60/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_60/assets
# Time used for epoch 61 are 2969.53 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_61/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_61/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_61/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_61/assets
# Time used for epoch 62 are 3018.18 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_62/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_62/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_62/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_62/assets
# Time used for epoch 63 are 3066.81 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_63/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_63/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_63/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_63/assets
# Time used for epoch 64 are 3115.45 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_64/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_64/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_64/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_64/assets
# Time used for epoch 65 are 3164.10 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_65/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_65/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_65/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_65/assets
# Time used for epoch 66 are 3212.94 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_66/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_66/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_66/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_66/assets
# Time used for epoch 67 are 3261.61 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_67/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_67/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_67/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_67/assets
# Time used for epoch 68 are 3310.38 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_68/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_68/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_68/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_68/assets
# Time used for epoch 69 are 3359.26 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_69/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_69/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_69/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_69/assets
# Time used for epoch 70 are 3408.06 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_70/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_70/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_70/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_70/assets
# Time used for epoch 71 are 3457.04 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_71/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_71/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_71/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_71/assets
# Time used for epoch 72 are 3505.82 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_72/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_72/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_72/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_72/assets
# Time used for epoch 73 are 3554.44 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_73/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_73/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_73/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_73/assets
# Time used for epoch 74 are 3603.34 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_74/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_74/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_74/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_74/assets
# Time used for epoch 75 are 3652.14 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_75/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_75/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_75/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_75/assets
# Time used for epoch 76 are 3700.84 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_76/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_76/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_76/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_76/assets
# Time used for epoch 77 are 3749.51 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_77/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_77/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_77/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_77/assets
# Time used for epoch 78 are 3798.28 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_78/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_78/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_78/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_78/assets
# Time used for epoch 79 are 3847.17 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_79/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_79/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_79/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_79/assets
# Time used for epoch 80 are 3896.01 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_80/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_80/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_80/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_80/assets
# Time used for epoch 81 are 3944.92 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_81/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_81/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_81/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_81/assets
# Time used for epoch 82 are 3993.51 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_82/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_82/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_82/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_82/assets
# Time used for epoch 83 are 4042.51 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_83/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_83/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_83/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_83/assets
# Time used for epoch 84 are 4091.20 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_84/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_84/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_84/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_84/assets
# Time used for epoch 85 are 4139.93 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_85/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_85/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_85/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_85/assets
# Time used for epoch 86 are 4188.69 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_86/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_86/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_86/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_86/assets
# Time used for epoch 87 are 4237.42 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_87/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_87/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_87/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_87/assets
# Time used for epoch 88 are 4286.35 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_88/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_88/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_88/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_88/assets
# Time used for epoch 89 are 4335.17 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_89/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_89/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_89/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_89/assets
# Time used for epoch 90 are 4384.07 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_90/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_90/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_90/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_90/assets
# Time used for epoch 91 are 4432.62 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_91/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_91/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_91/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_91/assets
# Time used for epoch 92 are 4481.66 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_92/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_92/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_92/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_92/assets
# Time used for epoch 93 are 4530.35 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_93/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_93/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_93/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_93/assets
# Time used for epoch 94 are 4579.21 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_94/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_94/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_94/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_94/assets
# Time used for epoch 95 are 4628.16 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_95/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_95/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_95/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_95/assets
# Time used for epoch 96 are 4677.16 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_96/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_96/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_96/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_96/assets
# Time used for epoch 97 are 4725.84 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_97/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_97/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_97/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_97/assets
# Time used for epoch 98 are 4774.81 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_98/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_98/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_98/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_98/assets
# Time used for epoch 99 are 4823.58 seconds.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsD/epoch_99/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsG/epoch_99/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsDopt/epoch_99/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/GANvWGAN/WGAN2ndattempt/checkpointsGopt/epoch_99/assets
# Time used for epoch 100 are 4872.48 seconds.
# Done! 4873.04 seconds have passed.

# %%
model_param_GANfull100 = {'amsgrad_d': False,
 'amsgrad_g': False,
 'batch_size': 128,
 'beta_1_d': 0.2,
 'beta_1_g': 0.5,
 'beta_2_d': 0.999,
 'beta_2_g': 0.999,
 'critic_step': 1,
 'dataset': 'MNIST',
 'epsilon_d': 1e-07,
 'epsilon_g': 1e-07,
 'learning_rate_d': 0.0001,
 'learning_rate_g': 0.0001,
 'model': 'GAN',
 'noise_dim': 128,
 'output': '/content/drive/My Drive/GANvWGAN/GAN2ndattempt',
 'total_epoch': 100,
 'visualize': True,
  'gif': True}

random.seed(0)
run(False,model_param_GANfull100)
